# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # Dataframe in Pandas

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types

# %%
# Import dataset

# %%
#Current Path
pwd
# Out:
# 'C:\\Users\\Fingertips'

# %%
#change work directory
cd D:/Fingertips_Shalini/Desktop/Data Files
# Out:
# D:\Fingertips_Shalini\Desktop\Data Files

# %%
sales=pd.read_csv("100_Sales _Records.csv")
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27/06/2010     159.42     2533654.00
# 1        Online              C  15/09/2012     117.11      576782.80
# 2       Offline              L  05/08/2014     524.96     1158502.59
# 3        Online              C  07/05/2014       6.92       75591.66
# 4       Offline              L  02/06/2013     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# 4     639077.50

# %%
#Names of all columns in dataset
sales.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit'],
#       dtype='object')

# %%
#First 5 records of data
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27/06/2010     159.42     2533654.00
# 1        Online              C  15/09/2012     117.11      576782.80
# 2       Offline              L  05/08/2014     524.96     1158502.59
# 3        Online              C  07/05/2014       6.92       75591.66
# 4       Offline              L  02/06/2013     524.96     3296425.02
#
#    Total_Profit
# 0     951410.50
# 1     248406.36
# 2     224598.75
# 3      19525.82
# 4     639077.50

# %%
#Last 5 records of data
sales.tail()
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 95  Sub_Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub_Saharan Africa    Mozambique      Household       Offline
#
#    Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 95              M  09/03/2011      35.84       97040.64      65214.72
# 96              L  28/12/2011       6.92       58471.11      15103.47
# 97              C  29/06/2016      90.93      228779.10      93748.05
# 98              M  08/08/2015      56.67      471336.91     144521.02
# 99              L  15/02/2012     502.54     3586605.09     889472.91

# %%
#First 3 records of data
sales.head(3)
# Out:
#                               Region  Country        Item_Type Sales_Channel  \
# 0              Australia and Oceania   Tuvalu        Baby Food       Offline
# 1  Central America and the Caribbean  Grenada           Cereal        Online
# 2                             Europe   Russia  Office Supplies       Offline
#
#   Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 0              H  27/06/2010     159.42     2533654.00     951410.50
# 1              C  15/09/2012     117.11      576782.80     248406.36
# 2              L  05/08/2014     524.96     1158502.59     224598.75

# %%
#Last 3 records of data
sales.tail(3)
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub_Saharan Africa    Mozambique      Household       Offline
#
#    Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit
# 97              C  29/06/2016      90.93      228779.10      93748.05
# 98              M  08/08/2015      56.67      471336.91     144521.02
# 99              L  15/02/2012     502.54     3586605.09     889472.91

# %% [markdown]
# # Slicing & Dicing

# %% [markdown]
# # Data Selection

# %%
#select a single column(Selecting data using Labels (Column Headings))
sales['Region'].head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#Method 2: use the column name as an 'attribute'; gives the same output
sales.Region.head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#pass a list of column(select multiple columns)
sales[['Region','Total_Profit']].head()
# Out:
#                               Region  Total_Profit
# 0              Australia and Oceania     951410.50
# 1  Central America and the Caribbean     248406.36
# 2                             Europe     224598.75
# 3                 Sub_Saharan Africa      19525.82
# 4                 Sub_Saharan Africa     639077.50

# %%
#what if you flip the order
sales[['Total_Profit','Region']].head()
# Out:
#    Total_Profit                             Region
# 0     951410.50              Australia and Oceania
# 1     248406.36  Central America and the Caribbean
# 2     224598.75                             Europe
# 3      19525.82                 Sub_Saharan Africa
# 4     639077.50                 Sub_Saharan Africa

# %%
#create an object that only contain Region column
Region_data=sales['Region']
Region_data.head()
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# 2                               Europe
# 3                   Sub_Saharan Africa
# 4                   Sub_Saharan Africa
# Name: Region, dtype: object

# %%
#Creating a new column-new
sales['region_country']=sales['Region']+sales['Country']
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27/06/2010     159.42     2533654.00
# 1        Online              C  15/09/2012     117.11      576782.80
# 2       Offline              L  05/08/2014     524.96     1158502.59
# 3        Online              C  07/05/2014       6.92       75591.66
# 4       Offline              L  02/06/2013     524.96     3296425.02
#
#    Total_Profit                            region_country
# 0     951410.50               Australia and OceaniaTuvalu
# 1     248406.36  Central America and the CaribbeanGrenada
# 2     224598.75                              EuropeRussia
# 3      19525.82   Sub_Saharan AfricaSao Tome and Principe
# 4     639077.50                  Sub_Saharan AfricaRwanda

# %%
#Slicing Subsets of Rows in Python
#select first 3 rows
sales[0:3]
# Out:
#                               Region  Country        Item_Type Sales_Channel  \
# 0              Australia and Oceania   Tuvalu        Baby Food       Offline
# 1  Central America and the Caribbean  Grenada           Cereal        Online
# 2                             Europe   Russia  Office Supplies       Offline
#
#   Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0              H  27/06/2010     159.42     2533654.00     951410.50
# 1              C  15/09/2012     117.11      576782.80     248406.36
# 2              L  05/08/2014     524.96     1158502.59     224598.75
#
#                              region_country
# 0               Australia and OceaniaTuvalu
# 1  Central America and the CaribbeanGrenada
# 2                              EuropeRussia

# %%
#select first 5 rows
sales[:5]
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27/06/2010     159.42     2533654.00
# 1        Online              C  15/09/2012     117.11      576782.80
# 2       Offline              L  05/08/2014     524.96     1158502.59
# 3        Online              C  07/05/2014       6.92       75591.66
# 4       Offline              L  02/06/2013     524.96     3296425.02
#
#    Total_Profit                            region_country
# 0     951410.50               Australia and OceaniaTuvalu
# 1     248406.36  Central America and the CaribbeanGrenada
# 2     224598.75                              EuropeRussia
# 3      19525.82   Sub_Saharan AfricaSao Tome and Principe
# 4     639077.50                  Sub_Saharan AfricaRwanda

# %%
# Select the last row in the dataset
sales[-1:]
# Out:
#                 Region     Country  Item_Type Sales_Channel Order_Priority  \
# 99  Sub_Saharan Africa  Mozambique  Household       Offline              L
#
#      Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 99  15/02/2012     502.54     3586605.09     889472.91
#
#                   region_country
# 99  Sub_Saharan AfricaMozambique

# %% [markdown]
# # LOC

# %%
# Select all columns for rows of index values 0 and 10
sales.loc[[0, 10], :]
# Out:
#                    Region     Country   Item_Type Sales_Channel  \
# 0   Australia and Oceania      Tuvalu   Baby Food       Offline
# 10                   Asia  Kyrgyzstan  Vegetables        Online
#
#    Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0               H  27/06/2010     159.42     2533654.00     951410.50
# 10              H  07/12/2011      90.93       19103.44       7828.12
#
#                  region_country
# 0   Australia and OceaniaTuvalu
# 10               AsiaKyrgyzstan

# %%
# Select first row and specific column
sales.loc[0, ['Region', 'Country', 'Item_Type']]
# Out:
# Region       Australia and Oceania
# Country                     Tuvalu
# Item_Type                Baby Food
# Name: 0, dtype: object

# %%
sales.loc[[0, 10, 25],:]
# Out:
#                    Region     Country   Item_Type Sales_Channel  \
# 0   Australia and Oceania      Tuvalu   Baby Food       Offline
# 10                   Asia  Kyrgyzstan  Vegetables        Online
# 25                 Europe      France   Cosmetics        Online
#
#    Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0               H  27/06/2010     159.42     2533654.00     951410.50
# 10              H  07/12/2011      90.93       19103.44       7828.12
# 25              H  06/05/2017     263.33      793518.00     315574.05
#
#                  region_country
# 0   Australia and OceaniaTuvalu
# 10               AsiaKyrgyzstan
# 25                 EuropeFrance

# %%
#error
sales.loc[0:4,1:4]

# %%
#error
sales.loc[[0:4],:]

# %%
sales.loc[[0,4],:]
# Out:
#                   Region Country        Item_Type Sales_Channel  \
# 0  Australia and Oceania  Tuvalu        Baby Food       Offline
# 4     Sub_Saharan Africa  Rwanda  Office Supplies       Offline
#
#   Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0              H  27/06/2010     159.42     2533654.00      951410.5
# 4              L  02/06/2013     524.96     3296425.02      639077.5
#
#                 region_country
# 0  Australia and OceaniaTuvalu
# 4     Sub_Saharan AfricaRwanda

# %% [markdown]
# # ILOC

# %%
# Syntax for iloc indexing to finding a specific data element
sales.iloc[row, column]

# %%
#value in 2nd row and 6th column
sales.iloc[2,6]
# Out:
# 524.96000000000004

# %%
#Slicing Subsets of Rows and Columns in Python
# To select a subset of rows and columns from our DataFrame, 
# we can use the iloc method. For example, we can select month, day and year 
#(columns 2, 3 and 4 if we start counting at 1), like this:
#iloc[row slicing,column slicing]

# %%
sales.iloc[2:6,6:9]
# Out:
#    Unit_Cost  Total_Revenue  Total_Profit
# 2     524.96     1158502.59     224598.75
# 3       6.92       75591.66      19525.82
# 4     524.96     3296425.02     639077.50
# 5     159.42      759202.72     285087.64

# %% [markdown]
# # Subsetting & Filter

# %% [markdown]
# # Data selection based on Condition

# %%
#Subsetting Data using Criteria
sales
sales[sales.Sales_Channel == "Offline"]
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# 6                  Sub_Saharan Africa                 Angola        Household
# 8                  Sub_Saharan Africa  Republic of the Congo    Personal Care
# 11                 Sub_Saharan Africa             Cape Verde          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                               Asia               Mongolia    Personal Care
# 16                               Asia              Sri Lanka        Cosmetics
# 17                 Sub_Saharan Africa               Cameroon        Beverages
# 18                               Asia           Turkmenistan        Household
# 28                             Europe                 Norway        Beverages
# 29                 Sub_Saharan Africa             The Gambia        Household
# 30                             Europe            Switzerland        Cosmetics
# 31                 Sub_Saharan Africa            South Sudan    Personal Care
# 33                               Asia                Myanmar        Household
# 35  Central America and the Caribbean             Costa Rica    Personal Care
# 42                 Sub_Saharan Africa             The Gambia           Cereal
# 45                 Sub_Saharan Africa                Comoros           Cereal
# 48                             Europe              Macedonia          Clothes
# 49                 Sub_Saharan Africa             Mauritania  Office Supplies
# 53                 Sub_Saharan Africa           Sierra Leone  Office Supplies
# 54                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 56              Australia and Oceania                   Fiji          Clothes
# 57                             Europe                Austria        Cosmetics
# 59                 Sub_Saharan Africa               Djibouti        Cosmetics
# 60              Australia and Oceania              Australia           Cereal
# 63       Middle East and North Africa                  Libya          Clothes
# 64  Central America and the Caribbean                  Haiti        Cosmetics
# 65                 Sub_Saharan Africa                 Rwanda        Cosmetics
# 66                 Sub_Saharan Africa                  Gabon    Personal Care
# 67  Central America and the Caribbean                 Belize          Clothes
# 68                             Europe              Lithuania  Office Supplies
# 69                 Sub_Saharan Africa             Madagascar          Clothes
# 74       Middle East and North Africa               Pakistan        Cosmetics
# 75                      North America                 Mexico        Household
# 77                               Asia                   Laos       Vegetables
# 78                             Europe                 Monaco        Baby Food
# 80                             Europe                  Spain        Household
# 85                      North America                 Mexico    Personal Care
# 86                 Sub_Saharan Africa  Sao Tome and Principe        Beverages
# 87                 Sub_Saharan Africa             The Gambia        Baby Food
# 89                             Europe               Slovenia        Beverages
# 90                 Sub_Saharan Africa           Sierra Leone  Office Supplies
# 91              Australia and Oceania              Australia        Beverages
# 94  Central America and the Caribbean              Nicaragua        Beverages
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
#    Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0        Offline              H  27/06/2010     159.42     2533654.00
# 2        Offline              L  05/08/2014     524.96     1158502.59
# 4        Offline              L  02/06/2013     524.96     3296425.02
# 6        Offline              M  27/04/2011     502.54     2798046.49
# 8        Offline              M  25/08/2015      56.67      496101.10
# 11       Offline              H  19/08/2014      35.84      455479.04
# 13       Offline              H  13/02/2017     502.54     5997054.98
# 14       Offline              C  23/02/2014      56.67      400558.73
# 16       Offline              M  18/12/2016     263.33     3039414.40
# 17       Offline              C  18/04/2015      31.79      257653.50
# 18       Offline              L  20/01/2011     502.54     2559474.10
# 28       Offline              C  30/07/2014      31.79      243133.80
# 29       Offline              L  06/09/2012     502.54     1583799.90
# 30       Offline              M  20/10/2012     263.33     3786589.20
# 31       Offline              C  28/01/2014      56.67      173676.25
# 33       Offline              H  03/01/2015     502.54     5513227.50
# 35       Offline              L  21/05/2017      56.67      523807.57
# 42       Offline              H  06/08/2012     117.11      435466.90
# 45       Offline              H  29/04/2016     117.11      197883.40
# 48       Offline              C  14/11/2014      35.84      856973.76
# 49       Offline              C  13/01/2012     524.96      824431.86
# 53       Offline              M  01/07/2012     524.96     2251232.97
# 54       Offline              H  24/10/2013       6.92       71253.21
# 56       Offline              C  08/01/2010      35.84     1082418.40
# 57       Offline              H  03/02/2015     263.33     1244708.40
# 59       Offline              H  19/04/2014     263.33     3154398.00
# 60       Offline              H  07/02/2013     117.11      140287.40
# 63       Offline              H  17/11/2010      35.84      668356.48
# 64       Offline              H  16/11/2013     263.33      745426.00
# 65       Offline              H  25/11/2013     263.33     1957344.40
# 66       Offline              L  07/09/2012      56.67      707454.88
# 67       Offline              M  09/07/2016      35.84      600821.44
# 68       Offline              H  17/11/2010     524.96     5396577.27
# 69       Offline              L  28/05/2015      35.84      802333.76
# 74       Offline              L  16/08/2013     263.33     4324782.40
# 75       Offline              C  12/12/2014     502.54     4647149.58
# 77       Offline              C  23/10/2011      90.93      574951.92
# 78       Offline              H  06/02/2012     159.42     2198981.92
# 80       Offline              L  30/11/2012     502.54     3015902.51
# 85       Offline              L  20/03/2012      56.67      524870.06
# 86       Offline              C  21/01/2011      31.79      418936.05
# 87       Offline              M  20/03/2014     159.42     1419101.52
# 89       Offline              C  25/11/2016      31.79      221117.00
# 90       Offline              H  14/12/2016     524.96      617347.08
# 91       Offline              H  07/11/2014      31.79      445508.05
# 94       Offline              C  21/03/2011      31.79      387002.20
# 96       Offline              L  28/12/2011       6.92       58471.11
# 97       Offline              C  29/06/2016      90.93      228779.10
# 98       Offline              M  08/08/2015      56.67      471336.91
# 99       Offline              L  15/02/2012     502.54     3586605.09
#
#     Total_Profit                               region_country
# 0      951410.50                  Australia and OceaniaTuvalu
# 2      224598.75                                 EuropeRussia
# 4      639077.50                     Sub_Saharan AfricaRwanda
# 6      693911.51                     Sub_Saharan AfricaAngola
# 8      152114.20      Sub_Saharan AfricaRepublic of the Congo
# 11     306097.92                 Sub_Saharan AfricaCape Verde
# 13    1487261.02    Central America and the CaribbeanHonduras
# 14     122819.06                                 AsiaMongolia
# 16    1208744.24                                AsiaSri Lanka
# 17      85033.80                   Sub_Saharan AfricaCameroon
# 18     634745.90                             AsiaTurkmenistan
# 28      80241.84                                 EuropeNorway
# 29     392780.10                 Sub_Saharan AfricaThe Gambia
# 30    1505888.07                            EuropeSwitzerland
# 31      53252.50                Sub_Saharan AfricaSouth Sudan
# 33    1367272.50                                  AsiaMyanmar
# 35     160609.54  Central America and the CaribbeanCosta Rica
# 42     187545.03                 Sub_Saharan AfricaThe Gambia
# 45      85223.58                    Sub_Saharan AfricaComoros
# 48     575916.48                              EuropeMacedonia
# 49     159832.50                 Sub_Saharan AfricaMauritania
# 53     436446.25               Sub_Saharan AfricaSierra Leone
# 54      18405.17      Sub_Saharan AfricaSao Tome and Principe
# 56     727423.20                    Australia and OceaniaFiji
# 57     495007.89                                EuropeAustria
# 59    1254472.05                   Sub_Saharan AfricaDjibouti
# 60      60418.38               Australia and OceaniaAustralia
# 63     449159.04            Middle East and North AfricaLibya
# 64     296448.35       Central America and the CaribbeanHaiti
# 65     778415.99                     Sub_Saharan AfricaRwanda
# 66     216919.36                      Sub_Saharan AfricaGabon
# 67     403773.12      Central America and the CaribbeanBelize
# 68    1046233.75                              EuropeLithuania
# 69     539196.48                 Sub_Saharan AfricaMadagascar
# 74    1719922.04         Middle East and North AfricaPakistan
# 75    1152486.42                          North AmericaMexico
# 77     235601.16                                     AsiaLaos
# 78     825738.04                                 EuropeMonaco
# 80     747939.49                                  EuropeSpain
# 85     160935.32                          North AmericaMexico
# 86     138262.14      Sub_Saharan AfricaSao Tome and Principe
# 87     532885.74                 Sub_Saharan AfricaThe Gambia
# 89      72975.60                               EuropeSlovenia
# 90     119685.00               Sub_Saharan AfricaSierra Leone
# 91     147031.74               Australia and OceaniaAustralia
# 94     127722.96   Central America and the CaribbeanNicaragua
# 96      15103.47                                 AsiaMalaysia
# 97      93748.05               Sub_Saharan AfricaSierra Leone
# 98     144521.02                          North AmericaMexico
# 99     889472.91                 Sub_Saharan AfricaMozambique

# %%
sales
sales[sales.Sales_Channel != "Offline"]
# Out:
#                                Region                           Country  \
# 1   Central America and the Caribbean                           Grenada
# 3                  Sub_Saharan Africa             Sao Tome and Principe
# 5               Australia and Oceania                   Solomon Islands
# 7                  Sub_Saharan Africa                      Burkina Faso
# 9                  Sub_Saharan Africa                           Senegal
# 10                               Asia                        Kyrgyzstan
# 12                               Asia                        Bangladesh
# 15                             Europe                          Bulgaria
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# 21                             Europe                          Portugal
# 22  Central America and the Caribbean                          Honduras
# 23              Australia and Oceania                       New Zealand
# 24                             Europe                          Moldova
# 25                             Europe                            France
# 26              Australia and Oceania                          Kiribati
# 27                 Sub_Saharan Africa                              Mali
# 32              Australia and Oceania                         Australia
# 34                 Sub_Saharan Africa                          Djibouti
# 36       Middle East and North Africa                             Syria
# 37                 Sub_Saharan Africa                        The Gambia
# 38                               Asia                            Brunei
# 39                             Europe                          Bulgaria
# 40                 Sub_Saharan Africa                             Niger
# 41       Middle East and North Africa                        Azerbaijan
# 43                             Europe                          Slovakia
# 44                               Asia                           Myanmar
# 46                             Europe                           Iceland
# 47                             Europe                       Switzerland
# 50                             Europe                           Albania
# 51                 Sub_Saharan Africa                           Lesotho
# 52       Middle East and North Africa                      Saudi Arabia
# 55                 Sub_Saharan Africa                     Cote d'Ivoire
# 58                             Europe                    United Kingdom
# 61                             Europe                        San Marino
# 62                 Sub_Saharan Africa                          Cameroon
# 70                               Asia                      Turkmenistan
# 71       Middle East and North Africa                             Libya
# 72                 Sub_Saharan Africa  Democratic Republic of the Congo
# 73                 Sub_Saharan Africa                          Djibouti
# 76              Australia and Oceania    Federated States of Micronesia
# 79              Australia and Oceania                            Samoa
# 81       Middle East and North Africa                           Lebanon
# 82       Middle East and North Africa                              Iran
# 83                 Sub_Saharan Africa                            Zambia
# 84                 Sub_Saharan Africa                             Kenya
# 88       Middle East and North Africa                            Kuwait
# 92       Middle East and North Africa                        Azerbaijan
# 93                             Europe                           Romania
# 95                 Sub_Saharan Africa                              Mali
#
#           Item_Type Sales_Channel Order_Priority   Ship_Date  Unit_Cost  \
# 1            Cereal        Online              C  15/09/2012     117.11
# 3            Fruits        Online              C  07/05/2014       6.92
# 5         Baby Food        Online              C  21/02/2015     159.42
# 7        Vegetables        Online              H  27/07/2012      90.93
# 9            Cereal        Online              H  30/05/2014     117.11
# 10       Vegetables        Online              H  07/12/2011      90.93
# 12          Clothes        Online              L  03/01/2017      35.84
# 15          Clothes        Online              M  06/03/2012      35.84
# 19             Meat        Online              L  09/11/2012     364.69
# 20        Baby Food        Online              L  28/06/2014     159.42
# 21        Baby Food        Online              H  09/03/2015     159.42
# 22           Snacks        Online              L  26/07/2016      97.44
# 23           Fruits        Online              H  10/04/2014       6.92
# 24    Personal Care        Online              L  05/10/2016      56.67
# 25        Cosmetics        Online              H  06/05/2017     263.33
# 26           Fruits        Online              M  11/10/2014       6.92
# 27           Fruits        Online              L  05/10/2010       6.92
# 32  Office Supplies        Online              C  25/11/2015     524.96
# 34           Snacks        Online              M  25/02/2017      97.44
# 36           Fruits        Online              L  12/03/2011       6.92
# 37             Meat        Online              M  23/01/2017     364.69
# 38  Office Supplies        Online              L  05/08/2012     524.96
# 39  Office Supplies        Online              M  28/02/2012     524.96
# 40    Personal Care        Online              H  28/03/2017      56.67
# 41        Cosmetics        Online              M  25/02/2010     263.33
# 43       Vegetables        Online              H  11/10/2012      90.93
# 44          Clothes        Online              H  18/11/2015      35.84
# 46        Cosmetics        Online              C  31/12/2016     263.33
# 47    Personal Care        Online              M  31/01/2011      56.67
# 50          Clothes        Online              C  18/03/2010      35.84
# 51           Fruits        Online              L  18/09/2013       6.92
# 52           Cereal        Online              M  28/03/2013     117.11
# 55          Clothes        Online              C  27/06/2012      35.84
# 58        Household        Online              L  14/02/2012     502.54
# 61        Baby Food        Online              L  07/01/2013     159.42
# 62  Office Supplies        Online              M  15/11/2011     524.96
# 70  Office Supplies        Online              M  20/05/2013     524.96
# 71           Fruits        Online              L  30/09/2015       6.92
# 72        Beverages        Online              C  15/07/2011      31.79
# 73           Cereal        Online              H  17/06/2017     117.11
# 76        Beverages        Online              C  15/11/2014      31.79
# 79        Cosmetics        Online              H  08/07/2013     263.33
# 81          Clothes        Online              L  10/08/2012      35.84
# 82        Cosmetics        Online              H  12/08/2016     263.33
# 83           Snacks        Online              L  01/05/2011      97.44
# 84       Vegetables        Online              L  04/07/2012      90.93
# 88           Fruits        Online              M  18/05/2012       6.92
# 92  Office Supplies        Online              M  24/07/2012     524.96
# 93        Cosmetics        Online              H  25/12/2010     263.33
# 95          Clothes        Online              M  09/03/2011      35.84
#
#     Total_Revenue  Total_Profit  \
# 1       576782.80     248406.36
# 3        75591.66      19525.82
# 5       759202.72     285087.64
# 7      1245112.92     510216.66
# 9      1356180.10     584073.87
# 10       19103.44       7828.12
# 12      902980.64     606834.72
# 15      182825.44     122865.12
# 19     2492526.12     337937.60
# 20     1901836.00     714157.00
# 21      324971.44     122029.78
# 22      339490.50     122686.50
# 23       20404.71       5270.67
# 24      414371.10     127054.20
# 25      793518.00     315574.05
# 26       50363.34      13009.18
# 27       54319.26      14031.02
# 32     1904138.04     369155.00
# 34     1117953.66     404010.78
# 36       35304.72       9119.44
# 37     2011149.63     272672.40
# 38     4368316.68     846885.00
# 39     2596374.27     503358.75
# 40      246415.95      75555.90
# 41     3162704.80    1257775.58
# 43       26344.26      10795.23
# 44      648030.40     435499.20
# 46     3876652.40    1541705.29
# 47       22312.29       6841.38
# 50      247956.32     166635.36
# 51       89623.98      23150.46
# 52      835759.10     359941.17
# 55      380512.96     255718.08
# 58      188452.14      46735.86
# 61     1212580.00     455335.00
# 62     3593376.78     696647.50
# 70     3262562.10     632512.50
# 71        6279.09       1621.93
# 72      272410.45      89904.06
# 73     1780539.20     766835.04
# 76      445033.55     146875.14
# 79     4220728.80    1678540.98
# 81      861563.52     579000.96
# 82     2836990.80    1128242.43
# 83      623289.30     225246.90
# 84      994765.42     407630.41
# 88        4870.26       1258.02
# 92     1316095.41     255151.25
# 93     3458252.00    1375311.70
# 95       97040.64      65214.72
#
#                                        region_country
# 1            Central America and the CaribbeanGrenada
# 3             Sub_Saharan AfricaSao Tome and Principe
# 5                Australia and OceaniaSolomon Islands
# 7                      Sub_Saharan AfricaBurkina Faso
# 9                           Sub_Saharan AfricaSenegal
# 10                                     AsiaKyrgyzstan
# 12                                     AsiaBangladesh
# 15                                     EuropeBulgaria
# 19                    Australia and OceaniaEast Timor
# 20                                       EuropeNorway
# 21                                     EuropePortugal
# 22          Central America and the CaribbeanHonduras
# 23                   Australia and OceaniaNew Zealand
# 24                                     EuropeMoldova
# 25                                       EuropeFrance
# 26                      Australia and OceaniaKiribati
# 27                             Sub_Saharan AfricaMali
# 32                     Australia and OceaniaAustralia
# 34                         Sub_Saharan AfricaDjibouti
# 36                  Middle East and North AfricaSyria
# 37                       Sub_Saharan AfricaThe Gambia
# 38                                         AsiaBrunei
# 39                                     EuropeBulgaria
# 40                            Sub_Saharan AfricaNiger
# 41             Middle East and North AfricaAzerbaijan
# 43                                     EuropeSlovakia
# 44                                        AsiaMyanmar
# 46                                      EuropeIceland
# 47                                  EuropeSwitzerland
# 50                                      EuropeAlbania
# 51                          Sub_Saharan AfricaLesotho
# 52           Middle East and North AfricaSaudi Arabia
# 55                    Sub_Saharan AfricaCote d'Ivoire
# 58                               EuropeUnited Kingdom
# 61                                   EuropeSan Marino
# 62                         Sub_Saharan AfricaCameroon
# 70                                   AsiaTurkmenistan
# 71                  Middle East and North AfricaLibya
# 72  Sub_Saharan AfricaDemocratic Republic of the C...
# 73                         Sub_Saharan AfricaDjibouti
# 76  Australia and OceaniaFederated States of Micro...
# 79                        Australia and OceaniaSamoa
# 81                Middle East and North AfricaLebanon
# 82                   Middle East and North AfricaIran
# 83                           Sub_Saharan AfricaZambia
# 84                            Sub_Saharan AfricaKenya
# 88                 Middle East and North AfricaKuwait
# 92             Middle East and North AfricaAzerbaijan
# 93                                      EuropeRomania
# 95                             Sub_Saharan AfricaMali

# %%
# baby food, cereal, unit cost> 100
sales[(sales.Total_Profit >= 150000) & (sales.Total_Revenue >= 50000)].head()
# Out:
#                               Region          Country        Item_Type  \
# 0              Australia and Oceania           Tuvalu        Baby Food
# 1  Central America and the Caribbean          Grenada           Cereal
# 2                             Europe           Russia  Office Supplies
# 4                 Sub_Saharan Africa           Rwanda  Office Supplies
# 5              Australia and Oceania  Solomon Islands        Baby Food
#
#   Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27/06/2010     159.42     2533654.00
# 1        Online              C  15/09/2012     117.11      576782.80
# 2       Offline              L  05/08/2014     524.96     1158502.59
# 4       Offline              L  02/06/2013     524.96     3296425.02
# 5        Online              C  21/02/2015     159.42      759202.72
#
#    Total_Profit                            region_country
# 0     951410.50               Australia and OceaniaTuvalu
# 1     248406.36  Central America and the CaribbeanGrenada
# 2     224598.75                              EuropeRussia
# 4     639077.50                  Sub_Saharan AfricaRwanda
# 5     285087.64      Australia and OceaniaSolomon Islands

# %% [markdown]
# # Descriptive Statistics

# %%
sales.mean()
# Out:
# Unit_Cost        1.910480e+02
# Total_Revenue    1.373488e+06
# Total_Profit     4.416820e+05
# dtype: float64

# %%
sales.max()
# Out:
# Region                  Sub_Saharan Africa
# Country                             Zambia
# Item_Type                       Vegetables
# Sales_Channel                       Online
# Order_Priority                           M
# Ship_Date                       31/12/2016
# Unit_Cost                           524.96
# Total_Revenue                  5.99705e+06
# Total_Profit                   1.71992e+06
# region_country    Sub_Saharan AfricaZambia
# dtype: object

# %%
sales.min()
# Out:
# Region                      Asia
# Country                  Albania
# Item_Type              Baby Food
# Sales_Channel            Offline
# Order_Priority                 C
# Ship_Date             01/05/2011
# Unit_Cost                   6.92
# Total_Revenue            4870.26
# Total_Profit             1258.02
# region_country    AsiaBangladesh
# dtype: object

# %%
sales.median()
# Out:
# Unit_Cost           107.275
# Total_Revenue    752314.360
# Total_Profit     290767.995
# dtype: float64

# %%
sales.std()
# Out:
# Unit_Cost        1.882082e+02
# Total_Revenue    1.460029e+06
# Total_Profit     4.385379e+05
# dtype: float64

# %%
sales.var()
# Out:
# Unit_Cost        3.542232e+04
# Total_Revenue    2.131684e+12
# Total_Profit     1.923155e+11
# dtype: float64

# %% [markdown]
# The describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
sales.describe()
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit
# count  100.000000   1.000000e+02  1.000000e+02
# mean   191.048000   1.373488e+06  4.416820e+05
# std    188.208181   1.460029e+06  4.385379e+05
# min      6.920000   4.870260e+03  1.258020e+03
# 25%     35.840000   2.687212e+05  1.214436e+05
# 50%    107.275000   7.523144e+05  2.907680e+05
# 75%    263.330000   2.212045e+06  6.358288e+05
# max    524.960000   5.997055e+06  1.719922e+06

# %% [markdown]
# info() function is used to get a concise summary of the dataframe

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
# Region            100 non-null object
# Country           100 non-null object
# Item_Type         100 non-null object
# Sales_Channel     100 non-null object
# Order_Priority    100 non-null object
# Ship_Date         100 non-null object
# Unit_Cost         100 non-null float64
# Total_Revenue     100 non-null float64
# Total_Profit      100 non-null float64
# region_country    100 non-null object
# dtypes: float64(3), object(7)
# memory usage: 7.9+ KB

# %%
#check datatype
sales.dtypes['Region']
# Out:
# dtype('O')

# %%
sales.dtypes['Total_Profit']
# Out:
# dtype('float64')

# %% [markdown]
# count() function return count of values in each elements

# %%
sales.count()
# Out:
# Region            100
# Country           100
# Sales_Channel     100
# Order_Priority    100
# Ship_Date         100
# Unit_Cost         100
# Total_Revenue     100
# Total_Profit      100
# region_country    100
# dtype: int64

# %%
# skew() function return unbiased skew over requested axis
sales.skew()
# Out:
# Unit_Cost        0.858072
# Total_Revenue    1.277698
# Total_Profit     1.238555
# dtype: float64

# %%
#kurt() function return unbiased kurtosis over requested axis
sales.kurt()
# Out:
# Unit_Cost       -0.830099
# Total_Revenue    0.804539
# Total_Profit     0.767398
# dtype: float64

# %%
#Compute pairwise correlation of columns, excluding NA/null values. 

sales.corr()
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost       1.000000       0.715623      0.467214
# Total_Revenue   0.715623       1.000000      0.897327
# Total_Profit    0.467214       0.897327      1.000000

# %%
#Covariance is a measure of how much two random variables vary together.
#The cov() function is used to compute pairwise covariance of columns, excluding NA/null values. 

sales.cov()
# Out:
#                   Unit_Cost  Total_Revenue  Total_Profit
# Unit_Cost      3.542232e+04   1.966455e+08  3.856216e+07
# Total_Revenue  1.966455e+08   2.131684e+12  5.745386e+11
# Total_Profit   3.856216e+07   5.745386e+11  1.923155e+11

# %% [markdown]
# # Apply function

# %% [markdown]
# apply takes a function and applies it to all values of pandas series or dataframe

# %%
sales.apply(max)
# Out:
# Region                  Sub_Saharan Africa
# Country                             Zambia
# Item_Type                       Vegetables
# Sales_Channel                       Online
# Order_Priority                           M
# Ship_Date                       31/12/2016
# Unit_Cost                           524.96
# Total_Revenue                  5.99705e+06
# Total_Profit                   1.71992e+06
# region_country    Sub_Saharan AfricaZambia
# dtype: object

# %%
sales.apply(min)
# Out:
# Region                      Asia
# Country                  Albania
# Item_Type              Baby Food
# Sales_Channel            Offline
# Order_Priority                 C
# Ship_Date             01/05/2011
# Unit_Cost                   6.92
# Total_Revenue            4870.26
# Total_Profit             1258.02
# region_country    AsiaBangladesh
# dtype: object

# %% [markdown]
# # DROP ENTERIES/VALUES

# %% [markdown]
# # Drop Columns

# %%
#To remove column Region
Newdata=sales.drop(['Region'], axis=1)
Newdata.head()
# Out:
#                  Country        Item_Type Sales_Channel Order_Priority  \
# 0                 Tuvalu        Baby Food       Offline              H
# 1                Grenada           Cereal        Online              C
# 2                 Russia  Office Supplies       Offline              L
# 3  Sao Tome and Principe           Fruits        Online              C
# 4                 Rwanda  Office Supplies       Offline              L
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0  27/06/2010     159.42     2533654.00     951410.50
# 1  15/09/2012     117.11      576782.80     248406.36
# 2  05/08/2014     524.96     1158502.59     224598.75
# 3  07/05/2014       6.92       75591.66      19525.82
# 4  02/06/2013     524.96     3296425.02     639077.50
#
#                              region_country
# 0               Australia and OceaniaTuvalu
# 1  Central America and the CaribbeanGrenada
# 2                              EuropeRussia
# 3   Sub_Saharan AfricaSao Tome and Principe
# 4                  Sub_Saharan AfricaRwanda

# %%
#To make permanent change in the dataset

sales.drop(['Item_Type'], axis=1,inplace=True)
sales.head()
# Out:
#                               Region                Country Sales_Channel  \
# 0              Australia and Oceania                 Tuvalu       Offline
# 1  Central America and the Caribbean                Grenada        Online
# 2                             Europe                 Russia       Offline
# 3                 Sub_Saharan Africa  Sao Tome and Principe        Online
# 4                 Sub_Saharan Africa                 Rwanda       Offline
#
#   Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0              H  27/06/2010     159.42     2533654.00     951410.50
# 1              C  15/09/2012     117.11      576782.80     248406.36
# 2              L  05/08/2014     524.96     1158502.59     224598.75
# 3              C  07/05/2014       6.92       75591.66      19525.82
# 4              L  02/06/2013     524.96     3296425.02     639077.50
#
#                              region_country
# 0               Australia and OceaniaTuvalu
# 1  Central America and the CaribbeanGrenada
# 2                              EuropeRussia
# 3   Sub_Saharan AfricaSao Tome and Principe
# 4                  Sub_Saharan AfricaRwanda

# %%
# Remove more than one column
sales.drop(['Region','Total_Profit'],axis=1).head()
# Out:
#                  Country Sales_Channel Order_Priority   Ship_Date  Unit_Cost  \
# 0                 Tuvalu       Offline              H  27/06/2010     159.42
# 1                Grenada        Online              C  15/09/2012     117.11
# 2                 Russia       Offline              L  05/08/2014     524.96
# 3  Sao Tome and Principe        Online              C  07/05/2014       6.92
# 4                 Rwanda       Offline              L  02/06/2013     524.96
#
#    Total_Revenue                            region_country
# 0     2533654.00               Australia and OceaniaTuvalu
# 1      576782.80  Central America and the CaribbeanGrenada
# 2     1158502.59                              EuropeRussia
# 3       75591.66   Sub_Saharan AfricaSao Tome and Principe
# 4     3296425.02                  Sub_Saharan AfricaRwanda

# %%
# Remove more than one column
sales.drop(['Region','Unit_Cost','Total_Profit'],axis=1).head()
# Out:
#                  Country Sales_Channel Order_Priority   Ship_Date  \
# 0                 Tuvalu       Offline              H  27/06/2010
# 1                Grenada        Online              C  15/09/2012
# 2                 Russia       Offline              L  05/08/2014
# 3  Sao Tome and Principe        Online              C  07/05/2014
# 4                 Rwanda       Offline              L  02/06/2013
#
#    Total_Revenue                            region_country
# 0     2533654.00               Australia and OceaniaTuvalu
# 1      576782.80  Central America and the CaribbeanGrenada
# 2     1158502.59                              EuropeRussia
# 3       75591.66   Sub_Saharan AfricaSao Tome and Principe
# 4     3296425.02                  Sub_Saharan AfricaRwanda

# %%
# Remove Multiple Columns in Python by indenxing
sales.drop(sales.columns[[0,2]], axis =1).head()
# Out:
#                  Country Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0                 Tuvalu              H  27/06/2010     159.42     2533654.00
# 1                Grenada              C  15/09/2012     117.11      576782.80
# 2                 Russia              L  05/08/2014     524.96     1158502.59
# 3  Sao Tome and Principe              C  07/05/2014       6.92       75591.66
# 4                 Rwanda              L  02/06/2013     524.96     3296425.02
#
#    Total_Profit                            region_country
# 0     951410.50               Australia and OceaniaTuvalu
# 1     248406.36  Central America and the CaribbeanGrenada
# 2     224598.75                              EuropeRussia
# 3      19525.82   Sub_Saharan AfricaSao Tome and Principe
# 4     639077.50                  Sub_Saharan AfricaRwanda

# %%
#Remove column count 3(Ship_Date)
sales.drop(sales.columns[3], axis =1).head()
# Out:
#                               Region                Country Sales_Channel  \
# 0              Australia and Oceania                 Tuvalu       Offline
# 1  Central America and the Caribbean                Grenada        Online
# 2                             Europe                 Russia       Offline
# 3                 Sub_Saharan Africa  Sao Tome and Principe        Online
# 4                 Sub_Saharan Africa                 Rwanda       Offline
#
#     Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0  27/06/2010     159.42     2533654.00     951410.50
# 1  15/09/2012     117.11      576782.80     248406.36
# 2  05/08/2014     524.96     1158502.59     224598.75
# 3  07/05/2014       6.92       75591.66      19525.82
# 4  02/06/2013     524.96     3296425.02     639077.50
#
#                              region_country
# 0               Australia and OceaniaTuvalu
# 1  Central America and the CaribbeanGrenada
# 2                              EuropeRussia
# 3   Sub_Saharan AfricaSao Tome and Principe
# 4                  Sub_Saharan AfricaRwanda

# %% [markdown]
# # Drop Rows

# %%
# Drop an observation (row)
sales.drop([1,2])
# Out:
#                                Region                           Country  \
# 0               Australia and Oceania                            Tuvalu
# 3                  Sub_Saharan Africa             Sao Tome and Principe
# 4                  Sub_Saharan Africa                            Rwanda
# 5               Australia and Oceania                   Solomon Islands
# 6                  Sub_Saharan Africa                            Angola
# 7                  Sub_Saharan Africa                      Burkina Faso
# 8                  Sub_Saharan Africa             Republic of the Congo
# 9                  Sub_Saharan Africa                           Senegal
# 10                               Asia                        Kyrgyzstan
# 11                 Sub_Saharan Africa                        Cape Verde
# 12                               Asia                        Bangladesh
# 13  Central America and the Caribbean                          Honduras
# 14                               Asia                          Mongolia
# 15                             Europe                          Bulgaria
# 16                               Asia                         Sri Lanka
# 17                 Sub_Saharan Africa                          Cameroon
# 18                               Asia                      Turkmenistan
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# 21                             Europe                          Portugal
# 22  Central America and the Caribbean                          Honduras
# 23              Australia and Oceania                       New Zealand
# 24                             Europe                          Moldova
# 25                             Europe                            France
# 26              Australia and Oceania                          Kiribati
# 27                 Sub_Saharan Africa                              Mali
# 28                             Europe                            Norway
# 29                 Sub_Saharan Africa                        The Gambia
# 30                             Europe                       Switzerland
# 31                 Sub_Saharan Africa                       South Sudan
# ..                                ...                               ...
# 70                               Asia                      Turkmenistan
# 71       Middle East and North Africa                             Libya
# 72                 Sub_Saharan Africa  Democratic Republic of the Congo
# 73                 Sub_Saharan Africa                          Djibouti
# 74       Middle East and North Africa                          Pakistan
# 75                      North America                            Mexico
# 76              Australia and Oceania    Federated States of Micronesia
# 77                               Asia                              Laos
# 78                             Europe                            Monaco
# 79              Australia and Oceania                            Samoa
# 80                             Europe                             Spain
# 81       Middle East and North Africa                           Lebanon
# 82       Middle East and North Africa                              Iran
# 83                 Sub_Saharan Africa                            Zambia
# 84                 Sub_Saharan Africa                             Kenya
# 85                      North America                            Mexico
# 86                 Sub_Saharan Africa             Sao Tome and Principe
# 87                 Sub_Saharan Africa                        The Gambia
# 88       Middle East and North Africa                            Kuwait
# 89                             Europe                          Slovenia
# 90                 Sub_Saharan Africa                      Sierra Leone
# 91              Australia and Oceania                         Australia
# 92       Middle East and North Africa                        Azerbaijan
# 93                             Europe                           Romania
# 94  Central America and the Caribbean                         Nicaragua
# 95                 Sub_Saharan Africa                              Mali
# 96                               Asia                          Malaysia
# 97                 Sub_Saharan Africa                      Sierra Leone
# 98                      North America                            Mexico
# 99                 Sub_Saharan Africa                        Mozambique
#
#    Sales_Channel Order_Priority   Ship_Date  Unit_Cost  Total_Revenue  \
# 0        Offline              H  27/06/2010     159.42     2533654.00
# 3         Online              C  07/05/2014       6.92       75591.66
# 4        Offline              L  02/06/2013     524.96     3296425.02
# 5         Online              C  21/02/2015     159.42      759202.72
# 6        Offline              M  27/04/2011     502.54     2798046.49
# 7         Online              H  27/07/2012      90.93     1245112.92
# 8        Offline              M  25/08/2015      56.67      496101.10
# 9         Online              H  30/05/2014     117.11     1356180.10
# 10        Online              H  07/12/2011      90.93       19103.44
# 11       Offline              H  19/08/2014      35.84      455479.04
# 12        Online              L  03/01/2017      35.84      902980.64
# 13       Offline              H  13/02/2017     502.54     5997054.98
# 14       Offline              C  23/02/2014      56.67      400558.73
# 15        Online              M  06/03/2012      35.84      182825.44
# 16       Offline              M  18/12/2016     263.33     3039414.40
# 17       Offline              C  18/04/2015      31.79      257653.50
# 18       Offline              L  20/01/2011     502.54     2559474.10
# 19        Online              L  09/11/2012     364.69     2492526.12
# 20        Online              L  28/06/2014     159.42     1901836.00
# 21        Online              H  09/03/2015     159.42      324971.44
# 22        Online              L  26/07/2016      97.44      339490.50
# 23        Online              H  10/04/2014       6.92       20404.71
# 24        Online              L  05/10/2016      56.67      414371.10
# 25        Online              H  06/05/2017     263.33      793518.00
# 26        Online              M  11/10/2014       6.92       50363.34
# 27        Online              L  05/10/2010       6.92       54319.26
# 28       Offline              C  30/07/2014      31.79      243133.80
# 29       Offline              L  06/09/2012     502.54     1583799.90
# 30       Offline              M  20/10/2012     263.33     3786589.20
# 31       Offline              C  28/01/2014      56.67      173676.25
# ..           ...            ...         ...        ...            ...
# 70        Online              M  20/05/2013     524.96     3262562.10
# 71        Online              L  30/09/2015       6.92        6279.09
# 72        Online              C  15/07/2011      31.79      272410.45
# 73        Online              H  17/06/2017     117.11     1780539.20
# 74       Offline              L  16/08/2013     263.33     4324782.40
# 75       Offline              C  12/12/2014     502.54     4647149.58
# 76        Online              C  15/11/2014      31.79      445033.55
# 77       Offline              C  23/10/2011      90.93      574951.92
# 78       Offline              H  06/02/2012     159.42     2198981.92
# 79        Online              H  08/07/2013     263.33     4220728.80
# 80       Offline              L  30/11/2012     502.54     3015902.51
# 81        Online              L  10/08/2012      35.84      861563.52
# 82        Online              H  12/08/2016     263.33     2836990.80
# 83        Online              L  01/05/2011      97.44      623289.30
# 84        Online              L  04/07/2012      90.93      994765.42
# 85       Offline              L  20/03/2012      56.67      524870.06
# 86       Offline              C  21/01/2011      31.79      418936.05
# 87       Offline              M  20/03/2014     159.42     1419101.52
# 88        Online              M  18/05/2012       6.92        4870.26
# 89       Offline              C  25/11/2016      31.79      221117.00
# 90       Offline              H  14/12/2016     524.96      617347.08
# 91       Offline              H  07/11/2014      31.79      445508.05
# 92        Online              M  24/07/2012     524.96     1316095.41
# 93        Online              H  25/12/2010     263.33     3458252.00
# 94       Offline              C  21/03/2011      31.79      387002.20
# 95        Online              M  09/03/2011      35.84       97040.64
# 96       Offline              L  28/12/2011       6.92       58471.11
# 97       Offline              C  29/06/2016      90.93      228779.10
# 98       Offline              M  08/08/2015      56.67      471336.91
# 99       Offline              L  15/02/2012     502.54     3586605.09
#
#     Total_Profit                                     region_country
# 0      951410.50                        Australia and OceaniaTuvalu
# 3       19525.82            Sub_Saharan AfricaSao Tome and Principe
# 4      639077.50                           Sub_Saharan AfricaRwanda
# 5      285087.64               Australia and OceaniaSolomon Islands
# 6      693911.51                           Sub_Saharan AfricaAngola
# 7      510216.66                     Sub_Saharan AfricaBurkina Faso
# 8      152114.20            Sub_Saharan AfricaRepublic of the Congo
# 9      584073.87                          Sub_Saharan AfricaSenegal
# 10       7828.12                                     AsiaKyrgyzstan
# 11     306097.92                       Sub_Saharan AfricaCape Verde
# 12     606834.72                                     AsiaBangladesh
# 13    1487261.02          Central America and the CaribbeanHonduras
# 14     122819.06                                       AsiaMongolia
# 15     122865.12                                     EuropeBulgaria
# 16    1208744.24                                      AsiaSri Lanka
# 17      85033.80                         Sub_Saharan AfricaCameroon
# 18     634745.90                                   AsiaTurkmenistan
# 19     337937.60                    Australia and OceaniaEast Timor
# 20     714157.00                                       EuropeNorway
# 21     122029.78                                     EuropePortugal
# 22     122686.50          Central America and the CaribbeanHonduras
# 23       5270.67                   Australia and OceaniaNew Zealand
# 24     127054.20                                     EuropeMoldova
# 25     315574.05                                       EuropeFrance
# 26      13009.18                      Australia and OceaniaKiribati
# 27      14031.02                             Sub_Saharan AfricaMali
# 28      80241.84                                       EuropeNorway
# 29     392780.10                       Sub_Saharan AfricaThe Gambia
# 30    1505888.07                                  EuropeSwitzerland
# 31      53252.50                      Sub_Saharan AfricaSouth Sudan
# ..           ...                                                ...
# 70     632512.50                                   AsiaTurkmenistan
# 71       1621.93                  Middle East and North AfricaLibya
# 72      89904.06  Sub_Saharan AfricaDemocratic Republic of the C...
# 73     766835.04                         Sub_Saharan AfricaDjibouti
# 74    1719922.04               Middle East and North AfricaPakistan
# 75    1152486.42                                North AmericaMexico
# 76     146875.14  Australia and OceaniaFederated States of Micro...
# 77     235601.16                                           AsiaLaos
# 78     825738.04                                       EuropeMonaco
# 79    1678540.98                        Australia and OceaniaSamoa
# 80     747939.49                                        EuropeSpain
# 81     579000.96                Middle East and North AfricaLebanon
# 82    1128242.43                   Middle East and North AfricaIran
# 83     225246.90                           Sub_Saharan AfricaZambia
# 84     407630.41                            Sub_Saharan AfricaKenya
# 85     160935.32                                North AmericaMexico
# 86     138262.14            Sub_Saharan AfricaSao Tome and Principe
# 87     532885.74                       Sub_Saharan AfricaThe Gambia
# 88       1258.02                 Middle East and North AfricaKuwait
# 89      72975.60                                     EuropeSlovenia
# 90     119685.00                     Sub_Saharan AfricaSierra Leone
# 91     147031.74                     Australia and OceaniaAustralia
# 92     255151.25             Middle East and North AfricaAzerbaijan
# 93    1375311.70                                      EuropeRomania
# 94     127722.96         Central America and the CaribbeanNicaragua
# 95      65214.72                             Sub_Saharan AfricaMali
# 96      15103.47                                       AsiaMalaysia
# 97      93748.05                     Sub_Saharan AfricaSierra Leone
# 98     144521.02                                North AmericaMexico
# 99     889472.91                       Sub_Saharan AfricaMozambique
#
# [98 rows x 9 columns]

# %% [markdown]
# # Drop Columns from a Dataframe using loc[] and drop() method

# %% [markdown]
# Drop Columns from a Dataframe using loc[] and drop() method

# %%
# Remove all columns between column name 'Country' to 'Total_Profit'
sales.drop(sales.loc[:, 'Country':'Total_Profit'].columns, axis = 1).head()
# Out:
#                               Region                            region_country
# 0              Australia and Oceania               Australia and OceaniaTuvalu
# 1  Central America and the Caribbean  Central America and the CaribbeanGrenada
# 2                             Europe                              EuropeRussia
# 3                 Sub_Saharan Africa   Sub_Saharan AfricaSao Tome and Principe
# 4                 Sub_Saharan Africa                  Sub_Saharan AfricaRwanda

# %% [markdown]
# # Drop Duplicates

# %%
data = {"StudentName": ["Reena", "Anil", "Mansi", "Jaman","Reena"],
        "Age": [24, 28, 26, 24,24],
        "Sex": ["Female", "Male", "Female", "Male","Female"]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Age     Sex StudentName
# 0   24  Female       Reena
# 1   28    Male        Anil
# 2   26  Female       Mansi
# 3   24    Male       Jaman
# 4   24  Female       Reena

# %% [markdown]
# # Drop Duplicate Rows
# #drop_duplicates returns only the dataframe’s unique values. Removing duplicate records is sample.

# %%
df = df.drop_duplicates()
print(df)
# Out:
#    Age     Sex StudentName
# 0   24  Female       Reena
# 1   28    Male        Anil
# 2   26  Female       Mansi
# 3   24    Male       Jaman

# %% [markdown]
# # Sorting Asceding and Desceding

# %%
#Sort Ascending(by defalut)
new_data = df.sort_values('Age')
new_data
# Out:
#    Age     Sex StudentName
# 0   24  Female       Reena
# 3   24    Male       Jaman
# 2   26  Female       Mansi
# 1   28    Male        Anil

# %%
# Sort Descending
new_data = df.sort_values('Age', ascending=False)
new_data
# Out:
#    Age     Sex StudentName
# 1   28    Male        Anil
# 2   26  Female       Mansi
# 0   24  Female       Reena
# 3   24    Male       Jaman

# %%
new_data = df.sort_values('StudentName', ascending=False)
new_data
# Out:
#    Age     Sex StudentName
# 0   24  Female       Reena
# 2   26  Female       Mansi
# 3   24    Male       Jaman
# 1   28    Male        Anil

# %% [markdown]
# # Concatenate

# %%
# Creating first dataframe 
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, 
                    index = [0, 1, 2, 3]) 
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
# Creating second dataframe 
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']}, 
                    index = [4, 5, 6, 7])
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
# Creating third dataframe 
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'], 
                    'B': ['B8', 'B9', 'B10', 'B11'], 
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']}, 
                    index = [8, 9, 10, 11])
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# Concatenating the dataframes 
pd.concat([df1, df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# # Group By

# %% [markdown]
# groupby() function is used to split the data into groups based on some criteria

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Sales_Channel', 'Order_Priority', 'Ship_Date',
#        'Unit_Cost', 'Total_Revenue', 'Total_Profit', 'region_country'],
#       dtype='object')

# %%
sales.groupby(['Sales_Channel']).mean()
# Out:
#                Unit_Cost  Total_Revenue  Total_Profit
# Sales_Channel
# Offline          216.823   1.581896e+06   498414.5334
# Online           165.273   1.165079e+06   384949.4346

# %%
sales.groupby(['Order_Priority']).sum().head()
# Out:
#                 Unit_Cost  Total_Revenue  Total_Profit
# Order_Priority
# C                 2760.33    18855063.05    6748328.46
# H                 5708.06    48749546.05   16891599.58
# L                 5689.05    36628127.46   10858727.86
# M                 4947.36    33116031.75    9669542.50

# %%
sales.groupby(['Region','Sales_Channel','Order_Priority']).count()['Unit_Cost'].head()
# Out:
# Region  Sales_Channel  Order_Priority
# Asia    Offline        C                 2
#                        H                 1
#                        L                 2
#                        M                 1
#         Online         H                 2
# Name: Unit_Cost, dtype: int64

# %% [markdown]
# # PIVOT Tables

# %%
pd.pivot_table(sales, index = ['Sales_Channel', 'Order_Priority'], aggfunc='sum')
# Out:
#                               Total_Profit  Total_Revenue  Unit_Cost
# Sales_Channel Order_Priority
# Offline       C                 3625315.71    10316782.15    1553.33
#               H                 9875825.95    31772954.03    3888.88
#               L                 6341300.86    22142428.99    3536.18
#               M                 5078284.15    14862644.03    1862.76
# Online        C                 3123012.75     8538280.90    1207.00
#               H                 7015773.63    16976592.02    1819.18
#               L                 4517427.00    14485698.47    2152.87
#               M                 4591258.35    18253387.72    3084.60

# %% [markdown]
# # Crosstab in Pandas

# %% [markdown]
# #crosstab() function in Python. This method is used to compute a simple cross-tabulation of two (or more) factors

# %%
pd.crosstab(sales['Sales_Channel'],sales.Unit_Cost)
# Out:
# Unit_Cost      6.92    31.79   35.84   56.67   90.93   97.44   117.11  159.42  \
# Sales_Channel
# Offline             2       6       6       7       2       0       3       3
# Online              8       2       7       3       4       3       4       4
#
# Unit_Cost      263.33  364.69  502.54  524.96
# Sales_Channel
# Offline             7       0       8       6
# Online              6       2       1       6

# %% [markdown]
# # Merge & Joins

# %%
user_usage = pd.read_csv("user_usage.csv")
user_device = pd.read_csv("user_device.csv")

# %%
user_usage.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
user_device.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %% [markdown]
# # Inner Merge-bydefault

# %%
result = pd.merge(user_usage,user_device,on='use_id',how='inner')
result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %% [markdown]
# # Select specific columns in joined

# %%
result = pd.merge(user_usage,
                 user_device[['use_id', 'platform', 'device']],
                 on='use_id')
result.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %% [markdown]
# # Left Merge

# %%
left_merge = pd.merge(user_usage,user_device,on='use_id',how='left')
left_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %% [markdown]
# # Right Merge

# %%
right_merge = pd.merge(user_usage,user_device,on='use_id',how='right')
right_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %% [markdown]
# # Outer Merge

# %%
outer_merge = pd.merge(user_usage,user_device,on='use_id',how='outer')
outer_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0
