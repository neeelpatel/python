# %%
pwd
# Out:
# 'C:\\Users\\Fingertips'

# %%
cd C:/Mehul Session/Session 27_Python Introduction
# Out:
# C:\Mehul Session\Session 27_Python Introduction

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("Replace_Sales.csv")
data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
data.dtypes
# Out:
# Date     object
# Age      object
# Sales    object
# Day      object
# dtype: object

# %%
new_data=data.replace(-99,value=np.NaN)

# %%
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
new_data = data.replace(-99, value=np.NaN)
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
#Replacing single value
new_data = data.replace(-99999, value=np.NaN)
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
new_data = data.replace(to_replace=[-909,-876], value=np.NaN)
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
#Replacing list with single value
new_data = data.replace(to_replace=[-909,-876], value=0)
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
data
# Out:
#          Date  Age  Sales        Day
# 0  01/01/2019   32      6     Monday
# 1  01/02/2019 -876      9    Tuesday
# 2  01/03/2019   28   -909  Wednesday
# 3  01/04/2019 -876      7        NaN
# 4  01/05/2019   32   -909     Monday
# 5  01/06/2019 -876   -909    Tuesday
# 6  01/07/2019 -876   -909        NaN
# 7  01/08/2019   34      8   Thrusday
# 8  01/09/2019   40     12    Tuesday

# %%
#Replacing per column
new_data = data.replace({
        'Age': -876,
        'Sales': -909,
        'Day': ''
    }, np.nan)
new_data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019       NaN     9    Tuesday
# 2  01/03/2019        28   NaN  Wednesday
# 3  01/04/2019       NaN     7        NaN
# 4  01/05/2019  32 Years   NaN     Monday
# 5  01/06/2019       NaN   NaN    Tuesday
# 6  01/07/2019       NaN   NaN        NaN
# 7  01/08/2019        34  8 Cr   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
data
# Out:
#          Date  Age  Sales        Day
# 0  01/01/2019   32      6     Monday
# 1  01/02/2019 -876      9    Tuesday
# 2  01/03/2019   28   -909  Wednesday
# 3  01/04/2019 -876      7        NaN
# 4  01/05/2019   32   -909     Monday
# 5  01/06/2019 -876   -909    Tuesday
# 6  01/07/2019 -876   -909        NaN
# 7  01/08/2019   34      8   Thrusday
# 8  01/09/2019   40     12    Tuesday

# %%
#Replacing special value by using mappinng


new_data = data.replace({
        -876: np.nan,   
        np.nan: 'Sunday',
    })
new_data
# Out:
#          Date   Age  Sales        Day
# 0  01/01/2019  32.0    6.0     Monday
# 1  01/02/2019   NaN    9.0    Tuesday
# 2  01/03/2019  28.0 -909.0  Wednesday
# 3  01/04/2019   NaN    7.0     Sunday
# 4  01/05/2019  32.0 -909.0     Monday
# 5  01/06/2019   NaN -909.0    Tuesday
# 6  01/07/2019   NaN -909.0     Sunday
# 7  01/08/2019  34.0    8.0   Thrusday
# 8  01/09/2019  40.0   12.0    Tuesday

# %%
data
# Out:
#          Date  Age  Sales        Day
# 0  01/01/2019   32      6     Monday
# 1  01/02/2019 -100      9    Tuesday
# 2  01/03/2019   28   -876  Wednesday
# 3  01/04/2019 -909      7        NaN
# 4  01/05/2019   32   -100     Monday
# 5  01/06/2019 -100   -100    Tuesday
# 6  01/07/2019 -100   -100        NaN
# 7  01/08/2019   34      8   Thrusday
# 8  01/09/2019   40     12    Tuesday

# %%
data
# Out:
#          Date       Age Sales        Day
# 0  01/01/2019  32 Years  6 Cr     Monday
# 1  01/02/2019      -100     9    Tuesday
# 2  01/03/2019  28 Years  -876  Wednesday
# 3  01/04/2019      -909  7 Cr        NaN
# 4  01/05/2019        32  -100     Monday
# 5  01/06/2019      -100  -100    Tuesday
# 6  01/07/2019      -100  -100        NaN
# 7  01/08/2019        34     8   Thrusday
# 8  01/09/2019        40    12    Tuesday

# %%
#Regex-Regular Expression
# when Age is 32 Years, Sales is 6 lacs etc.
new_data = data.replace({
    'Age': '[A-Za-z]', 
    'Sales': '[A-Za-z]'
},'', regex=True) 
new_data
# Out:
#          Date   Age Sales        Day
# 0  01/01/2019   32     6      Monday
# 1  01/02/2019  -100     9    Tuesday
# 2  01/03/2019   28   -876  Wednesday
# 3  01/04/2019  -909    7         NaN
# 4  01/05/2019    32  -100     Monday
# 5  01/06/2019  -100  -100    Tuesday
# 6  01/07/2019  -100  -100        NaN
# 7  01/08/2019    34     8   Thrusday
# 8  01/09/2019    40    12    Tuesday

# %%
#Replacing list with another list
#creating a new data frame
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['Maya', 'Rakesh', 'Rajiv', 'Harry', 'jinal', 'Shubham']
})
df
# Out:
#          score  student
# 0  exceptional     Maya
# 1      average   Rakesh
# 2         good    Rajiv
# 3         poor    Harry
# 4      average    jinal
# 5  exceptional  Shubham

# %%
new_df=df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
new_df
# Out:
#    score  student
# 0      4     Maya
# 1      2   Rakesh
# 2      3    Rajiv
# 3      1    Harry
# 4      2    jinal
# 5      4  Shubham

# %%
new_df.to_csv("new.csv")

# %%
#Write csv file/export csv file(it includes index)
data.to_csv("any.csv")
