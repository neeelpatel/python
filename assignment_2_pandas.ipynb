# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# 'F:\\neel\\fingertips\\python\\jupyternotbook'

# %%
data = pd.read_csv("NYC.csv")

# %%
data
# Out:
#    Survey                                           Question  Year  \
# 0     CHS                          Health Insurance Coverage  2014
# 1     CHS                          Health Insurance Coverage  2011
# 2     CHS                                     Binge Drinking  2011
# 3     CHS                                     Binge Drinking  2011
# 4     CHS                                 No Personal Doctor  2010
# ..    ...                                                ...   ...
# 95    CHS  Colon cancer screening, adults age 50+ (colono...  2010
# 96    CHS                                 No Personal Doctor  2012
# 97    CHS                    Did not get needed medical care  2014
# 98    CHS                          Health Insurance Coverage  2012
# 99    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2011
#
#     Prevalence  Lower95%CI  Upper95%CI
# 0         86.2        85.2        87.2
# 1         81.4        79.7        83.0
# 2         17.9        16.4        19.6
# ...

# %% [markdown]
# 1) Get first 5 rows of the dataset.

# %%
data.head()
# Out:
#   Survey                   Question  Year  Prevalence  Lower95%CI  Upper95%CI
# 0    CHS  Health Insurance Coverage  2014        86.2        85.2        87.2
# 1    CHS  Health Insurance Coverage  2011        81.4        79.7        83.0
# 2    CHS             Binge Drinking  2011        17.9        16.4        19.6
# 3    CHS             Binge Drinking  2011        17.9        16.4        19.6
# 4    CHS         No Personal Doctor  2010         NaN         NaN         NaN

# %% [markdown]
# 2) Get first 25 rows of the dataset.

# %%
data.head(25)
# Out:
#    Survey                                           Question  Year  \
# 0     CHS                          Health Insurance Coverage  2014
# 1     CHS                          Health Insurance Coverage  2011
# 2     CHS                                     Binge Drinking  2011
# 3     CHS                                     Binge Drinking  2011
# 4     CHS                                 No Personal Doctor  2010
# 5     CHS  Colon cancer screening, adults age 50+ (colono...  2011
# 6     CHS                                            Obesity  2014
# 7     CHS                                 No Personal Doctor  2013
# 8     CHS  Self-reported Health Status (excellent/very go...  2010
# 9     CHS  Drinks 1 or more sugar-sweetened beverages per...  2013
# 10    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2014
# 11    CHS                    Did not get needed medical care  2012
# 12    CHS  Drinks 1 or more sugar-sweetened beverages per...  2010
# ...

# %% [markdown]
# 3) Get the dataset from row 50.

# %%
data[50::]
# Out:
#    Survey                                           Question  Year  \
# 50    CHS  Self-reported Health Status (excellent/very go...  2013
# 51    CHS                                 No Personal Doctor  2011
# 52    CHS                          Health Insurance Coverage  2010
# 53    CHS  Drinks 1 or more sugar-sweetened beverages per...  2014
# 54    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2012
# 55    CHS  Colon cancer screening, adults age 50+ (colono...  2012
# 56    CHS                          Health Insurance Coverage  2013
# 57    CHS  Self-reported Health Status (excellent/very go...  2010
# 58    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2013
# 59    CHS                                     Binge Drinking  2010
# 60    CHS                   Smoking Status (current smokers)  2012
# 61    CHS  Colon cancer screening, adults age 50+ (colono...  2013
# 62    CHS  Self-reported Health Status (excellent/very go...  2011
# ...

# %% [markdown]
# 4) Get the first 3 rows and 5 columns from the dataset .

# %%
data.head()
# Out:
#   Survey                   Question  Year  Prevalence  Lower95%CI  Upper95%CI
# 0    CHS  Health Insurance Coverage  2014        86.2        85.2        87.2
# 1    CHS  Health Insurance Coverage  2011        81.4        79.7        83.0
# 2    CHS             Binge Drinking  2011        17.9        16.4        19.6
# 3    CHS             Binge Drinking  2011        17.9        16.4        19.6
# 4    CHS         No Personal Doctor  2010         NaN         NaN         NaN

# %%
data.iloc[0:3,0:5]
# Out:
#   Survey                   Question  Year  Prevalence  Lower95%CI
# 0    CHS  Health Insurance Coverage  2014        86.2        85.2
# 1    CHS  Health Insurance Coverage  2011        81.4        79.7
# 2    CHS             Binge Drinking  2011        17.9        16.4

# %% [markdown]
# 5) Display the Question answered by the first 7 rows of the dataset.

# %%
data['Question'].head(7).unique()
# Out:
# array(['Health Insurance Coverage', 'Binge Drinking',
#        'No Personal Doctor',
#        'Colon cancer screening, adults age 50+ (colonoscopy)', 'Obesity'],
#       dtype=object)

# %% [markdown]
# 6) Get the data for rows 0,10,99 from the dataset.

# %%
list1 = [0,10,99]
data.loc[list1,:]
# Out:
#    Survey                                           Question  Year  \
# 0     CHS                          Health Insurance Coverage  2014
# 10    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2014
# 99    CHS  Flu shot in last 12 months, adults ages 65+ (n...  2011
#
#     Prevalence  Lower95%CI  Upper95%CI
# 0         86.2        85.2        87.2
# 10        64.2        60.7        67.6
# 99        67.4        63.9        70.7

# %% [markdown]
# 7) Display Question, Year, Prevalence for all the rows in the dataset.

# %%
data.loc[:,['Question','Year','Prevalence']]
# Out:
#                                              Question  Year  Prevalence
# 0                           Health Insurance Coverage  2014        86.2
# 1                           Health Insurance Coverage  2011        81.4
# 2                                      Binge Drinking  2011        17.9
# 3                                      Binge Drinking  2011        17.9
# 4                                  No Personal Doctor  2010         NaN
# ..                                                ...   ...         ...
# 95  Colon cancer screening, adults age 50+ (colono...  2010        67.5
# 96                                 No Personal Doctor  2012        18.3
# 97                    Did not get needed medical care  2014         9.6
# 98                          Health Insurance Coverage  2012        80.2
# 99  Flu shot in last 12 months, adults ages 65+ (n...  2011        67.4
#
# [100 rows x 3 columns]

# %% [markdown]
# 8) Display Lower95%CI, Upper95%CI, for all the rows in the dataset.

# %%
data.loc[:,['Lower95%CI','Upper95%CI']]
# Out:
#     Lower95%CI  Upper95%CI
# 0         85.2        87.2
# 1         79.7        83.0
# 2         16.4        19.6
# 3         16.4        19.6
# 4          NaN         NaN
# ..         ...         ...
# 95        65.4        69.4
# 96        17.0        19.7
# 97         8.7        10.5
# 98        78.7        81.5
# 99        63.9        70.7
#
# [100 rows x 2 columns]

# %% [markdown]
# 9) Get the Year and the prevalence for the first 10 rows.

# %%
data.loc[:10,['Year','Prevalence']]
# Out:
#     Year  Prevalence
# 0   2014        86.2
# 1   2011        81.4
# 2   2011        17.9
# 3   2011        17.9
# 4   2010         NaN
# 5   2011        68.6
# 6   2014        24.7
# 7   2013        19.1
# 8   2010        79.1
# 9   2013        23.3
# 10  2014        64.2

# %% [markdown]
# 10) Get the Year for the last 10 rows in the dataset.

# %%
list1= data.tail(5)
data.loc[95:100,['Year']]
# Out:
#     Year
# 95  2010
# 96  2012
# 97  2014
# 98  2012
# 99  2011

# %% [markdown]
# 11) Get the Question and year for all the rows in the dataset.

# %%
data.loc[:,['Year','Question']]
# Out:
#     Year                                           Question
# 0   2014                          Health Insurance Coverage
# 1   2011                          Health Insurance Coverage
# 2   2011                                     Binge Drinking
# 3   2011                                     Binge Drinking
# 4   2010                                 No Personal Doctor
# ..   ...                                                ...
# 95  2010  Colon cancer screening, adults age 50+ (colono...
# 96  2012                                 No Personal Doctor
# 97  2014                    Did not get needed medical care
# 98  2012                          Health Insurance Coverage
# 99  2011  Flu shot in last 12 months, adults ages 65+ (n...
#
# [100 rows x 2 columns]

# %% [markdown]
# 12) Display the 3 columns from the dataset for the first 4 rows.

# %%
data.iloc[0:4,0:3]
# Out:
#   Survey                   Question  Year
# 0    CHS  Health Insurance Coverage  2014
# 1    CHS  Health Insurance Coverage  2011
# 2    CHS             Binge Drinking  2011
# 3    CHS             Binge Drinking  2011
